# %%
import pandas as pd
import matplotlib as plt

# %%
fletcher = pd.read_csv("tiempo_fletcher.csv")

# %%
fletcher.plot()

# %%
hammin = pd.read_csv("tiempo_hammin.csv")

# %%
hammin.plot()

# %%
completo = pd.read_csv("tiempo_completo.csv")

# %%
completo.plot()
